# %%
import datetime
import pandas as pd
import numpy as np
import pyodbc
import json
from urllib.parse import quote_plus
from sqlalchemy import create_engine, event,text

# %%
import json
f = open ('database_information.json', "r")
qq = json.loads(f.read())
f.close()
ini_cnt_str ='Driver={driver_str};Server=tcp:hkazdevsqld3vnreserch.database.windows.net,1433;database={database};Uid={username};Pwd={password};Encrypt=yes;Authentication=ActiveDirectoryPassword;Connection Timeout=30;'.format(**qq)
quoted = quote_plus(ini_cnt_str)
cnt_str = 'mssql+pyodbc:///?odbc_connect={}'.format(quoted)
engine = create_engine(cnt_str)

#Test Connection
try:
    conn = engine.connect()
    result = conn.execute(text("SELECT 1"))
    print("CONNECTION SUCESSFUL!")
except Exception as e:
    print("CONNECTION FAILED:",str(e))
# Out:
# CONNECTION SUCESSFUL!

# %%
data = pd.read_excel(r'doc\IP_Changelog_CleanIP.xlsx', sheet_name="Sheet1")
data
# Out:
#     Project_Key      Project_Name  \
# 0          3060        Phuoc Binh
# 1          3061      Phuoc Binh 2
# 2          2514     VSIP Bac Ninh
# 3          4686            Que Vo
# 4          4691     VSIP Bac Ninh
# 5          4715         Yen Phong
# 6          4716         Yen Phong
# 7          4698         Yen Phong
# 8          4699         Yen Phong
# 9          4717     VSIP Bac Ninh
# 10         4718      Yen Phong 2C
# 11         4687     VSIP Bac Ninh
# 12         4688     VSIP Bac Ninh
# 13         4689     VSIP Bac Ninh
# 14         4690     VSIP Bac Ninh
# 15         4694         Yen Phong
# 16         4695         Yen Phong
# 17         4696         Yen Phong
# 18         2522         Yen Phong
# 19         4710     VSIP Bac Ninh
# 20         4707         Yen Phong
# 21         4709     Thuan Thanh 2
# 22         4708  Nam Son Hap Linh
# 23         4712         Yen Phong
# 24         4711   VSIP Bac Ninh 2
# 25         4713    Thuan Thanh 3B
#
#                                      Sub_Project_Name   Latitude  Longtitude  \
# 0                                          Phuoc Binh  10.684859  107.101157
# 1                                        Phuoc Binh 2  10.727636  107.104707
# 2      Emergent Cold - Vsip Bac Ninh (Phase 1) Rbw Cs        NaN         NaN
# 3                                        Kinh Bac RBF        NaN         NaN
# 4                 VSIP Bac Ninh High-Rise Factory RBF        NaN         NaN
# 5                         KTG - Yen Phong Phase 1 RBF        NaN         NaN
# 6                         KTG - Yen Phong Phase 2 RBF        NaN         NaN
# 7                                 Dinh Le Factory RBF        NaN         NaN
# 8                              TWG Eco Industrial RBF        NaN         NaN
# 9                                            BWID RBF        NaN         NaN
# 10                               KTG Yen Phong 2C RBF        NaN         NaN
# 11                 FM Logistics Center Phase 1 RBW SD        NaN         NaN
# 12                            Linfox Warehouse RBW SD        NaN         NaN
# 13  Mapletree Logistics Park Bac Ninh (Phase 4-5) ...        NaN         NaN
# 14  Mapletree Logistics Park Bac Ninh (Phase 1-3) ...        NaN         NaN
# 15                  KTG - Yen Phong Phase 1 WH RBW SD        NaN         NaN
# 16                             Yusen Logistics RBW SD        NaN         NaN
# 17                                Logis Valley RBW SD        NaN         NaN
# 18                         ALS - VSIP Bac Ninh RBW CS        NaN         NaN
# 19                        LOGOS Logistics Park RBW SD        NaN         NaN
# 20                          SLP Park Yen Phong RBW SD        NaN         NaN
# 21                           SLP Park Bac Ninh RBW SD        NaN         NaN
# 22                   SLP Park Nam Son Hap Linh RBW SD        NaN         NaN
# 23                                        IDEC RBW SD        NaN         NaN
# 24                        BWID VSIP Bac Ninh 2 RBW SD        NaN         NaN
# 25        Mapletree Thuan Thanh Logistics Park RBW SD        NaN         NaN
#
#     Developer_Name Project_Type             District  City    Flag  \
# 0              NaN   Land Lease  Long Thanh District   NaN  update
# 1              NaN   Land Lease  Long Thanh District   NaN  update
# 2              NaN          NaN                  NaN   NaN   merge
# 3              NaN          NaN                  NaN   NaN  update
# 4              NaN          NaN                  NaN   NaN  update
# 5              NaN          NaN                  NaN   NaN  update
# 6              NaN          NaN                  NaN   NaN  update
# 7              NaN          NaN                  NaN   NaN  update
# 8              NaN          NaN                  NaN   NaN  update
# 9              NaN          NaN                  NaN   NaN  update
# 10             NaN          NaN                  NaN   NaN  update
# 11             NaN          NaN                  NaN   NaN  update
# 12             NaN          NaN                  NaN   NaN  update
# 13             NaN          NaN                  NaN   NaN  update
# 14             NaN          NaN                  NaN   NaN  update
# 15             NaN          NaN                  NaN   NaN  update
# 16             NaN          NaN                  NaN   NaN  update
# 17             NaN          NaN                  NaN   NaN  update
# 18             NaN          NaN                  NaN   NaN  update
# 19             NaN          NaN                  NaN   NaN  update
# 20             NaN          NaN                  NaN   NaN  update
# 21             NaN          NaN                  NaN   NaN  update
# 22             NaN          NaN                  NaN   NaN  update
# 23             NaN          NaN                  NaN   NaN  update
# 24             NaN          NaN                  NaN   NaN  update
# 25             NaN          NaN                  NaN   NaN  update
#
#    Update_column  Merge_key                            Update_project_name  \
# 0   project name        NaN                                     Phuoc Binh
# 1   project name        NaN                                     Phuoc Binh
# 2            NaN     4781.0                              Lineage Logistics
# 3   project name        NaN                                       Kinh Bac
# 4   project name        NaN                VSIP Bac Ninh High-Rise Factory
# 5   project name        NaN                        KTG - Yen Phong Phase 1
# 6   project name        NaN                        KTG - Yen Phong Phase 2
# 7   project name        NaN                                Dinh Le Factory
# 8   project name        NaN                             TWG Eco Industrial
# 9   project name        NaN                                           BWID
# 10  project name        NaN                               KTG Yen Phong 2C
# 11  project name        NaN                    FM Logistics Center Phase 1
# 12  project name        NaN                               Linfox Warehouse
# 13  project name        NaN  Mapletree Logistics Park Bac Ninh (Phase 4-5)
# 14  project name        NaN  Mapletree Logistics Park Bac Ninh (Phase 1-3)
# 15  project name        NaN                     KTG - Yen Phong Phase 1 WH
# 16  project name        NaN                                Yusen Logistics
# 17  project name        NaN                                   Logis Valley
# 18  project name        NaN                            ALS - VSIP Bac Ninh
# 19  project name        NaN                           LOGOS Logistics Park
# 20  project name        NaN                             SLP Park Yen Phong
# 21  project name        NaN                              SLP Park Bac Ninh
# 22  project name        NaN                      SLP Park Nam Son Hap Linh
# 23  project name        NaN                                           IDEC
# 24  project name        NaN                           BWID VSIP Bac Ninh 2
# 25  project name        NaN           Mapletree Thuan Thanh Logistics Park
#
#     Update_sub_project_name  Update_latitude  Update_longtitude  \
# 0                       NaN              NaN                NaN
# 1                       NaN              NaN                NaN
# 2                       NaN              NaN                NaN
# 3                       NaN              NaN                NaN
# 4                       NaN              NaN                NaN
# 5                       NaN              NaN                NaN
# 6                       NaN              NaN                NaN
# 7                       NaN              NaN                NaN
# 8                       NaN              NaN                NaN
# 9                       NaN              NaN                NaN
# 10                      NaN              NaN                NaN
# 11                      NaN              NaN                NaN
# 12                      NaN              NaN                NaN
# 13                      NaN              NaN                NaN
# 14                      NaN              NaN                NaN
# 15                      NaN              NaN                NaN
# 16                      NaN              NaN                NaN
# 17                      NaN              NaN                NaN
# 18                      NaN              NaN                NaN
# 19                      NaN              NaN                NaN
# 20                      NaN              NaN                NaN
# 21                      NaN              NaN                NaN
# 22                      NaN              NaN                NaN
# 23                      NaN              NaN                NaN
# 24                      NaN              NaN                NaN
# 25                      NaN              NaN                NaN
#
#     update_district  update_developer  Note
# 0               NaN               NaN   NaN
# 1               NaN               NaN   NaN
# 2               NaN               NaN   NaN
# 3               NaN               NaN   NaN
# 4               NaN               NaN   NaN
# 5               NaN               NaN   NaN
# 6               NaN               NaN   NaN
# 7               NaN               NaN   NaN
# 8               NaN               NaN   NaN
# 9               NaN               NaN   NaN
# 10              NaN               NaN   NaN
# 11              NaN               NaN   NaN
# 12              NaN               NaN   NaN
# 13              NaN               NaN   NaN
# 14              NaN               NaN   NaN
# 15              NaN               NaN   NaN
# 16              NaN               NaN   NaN
# 17              NaN               NaN   NaN
# 18              NaN               NaN   NaN
# 19              NaN               NaN   NaN
# 20              NaN               NaN   NaN
# 21              NaN               NaN   NaN
# 22              NaN               NaN   NaN
# 23              NaN               NaN   NaN
# 24              NaN               NaN   NaN
# 25              NaN               NaN   NaN

# %%
today=pd.to_datetime('today')
data['Import_Date']=today

# %%
try:
    data.to_sql('IP_Project_Manual_Update_P2', engine, index=False, if_exists='append', schema='DW')
except Exception as e:
    print("ERROR:",str(e))
